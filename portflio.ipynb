# %%
import pandas as pd
import numpy as np

from pandas_datareader import data as pdr
import yfinance as yf

# %%
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo(["AAPL", "AMZN", "CSCO", "IBM"], start="2024-03-01", end="2024-04-12")
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
data = data['Adj Close']

# %%
data.to_csv("data.csv")
